# %%
import dask.dataframe as dd
df = dd.read_parquet('D:/jn/Amazon_cs_proj/Issue_categor_proj_Phase1/cleaned_full_parquet')
df.head()
# Out:
#   marketplace  customer_id       review_id  product_id  product_parent  \
# 0          US   53096384.0   R63J84G1LOX6R  1563890119     763187671.0
# 1          US   53096399.0  R1BALOA11Z06MT  1559947608     381720534.0
# 2          US   53096332.0  R1LLAY5W5PZUS4  0671701800     860650224.0
# 3          US   53096335.0  R3R9VTJ82FXECQ  0425132153     624269601.0
# 4          US   51747709.0  R1P5J3FNBWTFXY  0517122707     161411385.0
#
#                                 product_title product_category star_rating  \
# 0  The Sandman Vol. 1: Preludes and Nocturnes            Books           4
# 1          The 22 Immutable Laws of Marketing            Books           4
# 2                                     Contact            Books           5
# 3                                  Good Omens            Books           5
# 4                     A Confederacy of Dunces            Books           5
#
#    helpful_votes total_votes vine verified_purchase  \
# ...

# %%
#import dask.dataframe as dd
#from dask.diagnostics import ProgressBar
#import re
#import nltk
#from dask.distributed import Client
#client = Client()  # Automatically uses all CPU cores


#----I/////O--------->
input_parquet_path = "D:/jn/Amazon_cs_proj/Issue_categor_proj_Phase1/cleaned_full_parquet"
output_path = "D:/jn/Amazon_cs_proj/Issue_categor_proj_Phase1/tokenized_reviews.parquet"

# === Step 1: Load Parquet ===
df = dd.read_parquet(input_parquet_path)

# === Step 2: Combine Headline + Body ===
df['combined_review'] = df['cleaned_review_headline'].fillna('') + ' ' + df['cleaned_review_body'].fillna('')

                                                       # === Step 3: Clean Combined Text (Optional but recommended) ===
#def clean_text(text):
#  return text

#df['combined_review'] = df['combined_review'].map(clean_text, meta=('combined_review', 'str'))

                                                                                        # === Step 4: Tokenize ===
#def tokenize_as_string(text):
  #  return ' '.join(re.findall(r'\b\w+\b', str(text).lower()))


#df['tokens'] = df['combined_review'].map(tokenize_as_string, meta=('tokens', 'object'))

# === Step 5: Drop raw columns if desired ===
df = df.drop(['review_headline', 'review_body'], axis=1, errors='ignore')  # avoid crash if missing

# === Step 6: Save to new Parquet ===
#with ProgressBar():
      df.to_parquet(output_path, write_index=False,engine='pyarrow')
print("ALLDONE and save to new",output_path)
# Out:
# ALLDONE and save to new D:/jn/Amazon_cs_proj/Issue_categor_proj_Phase1/tokenized_reviews.parquet

# %%
df=dd.read_parquet('D:/jn/Amazon_cs_proj/Issue_categor_proj_Phase1/tokenized_reviews.parquet')
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df=dd.read_parquet('D:/jn/Amazon_cs_proj/Issue_categor_proj_Phase1/tokenized_reviews.parquet')
#       2 df.head()
#
# NameError: name 'dd' is not defined

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.columns
#
# NameError: name 'df' is not defined
